# %% [markdown]
# # Blame: ES or SNN?
#
# This notebook contains three tasks for ES just to make sure it actaully works because it is apparently not working on SNN.

# %%
from EvolutionStrategy import ESParameter, ESModel

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.optim as optim

device = 'cuda'

# %% [markdown]
# ## 1. Test on Trivial Loss Landscape

# %%
def plot_landscape():
    # Create a meshgrid for X and Y
    x = np.linspace(-5, 5, 50)
    y = np.linspace(-5, 5, 50)
    X, Y = np.meshgrid(x, y)

    # Define a function for Z
    Z = (X**2 + Y**2) / 2

    # Create a figure and 3D axis
    fig = plt.figure(figsize=(6, 6))
    ax = fig.add_subplot(111, projection='3d')

    # Plot the surface
    ax.plot_surface(X, Y, Z, cmap='viridis')

    # Labels
    ax.set_xlabel('parameter 1')
    ax.set_ylabel('parameter 2')

    ax.set_title('quadratic loss surface')

    # Show the plot
    # plt.tight_layout()
    plt.show()
    
plot_landscape()

# %%
def quadratic_landscape(params):
    # params is of dimension: [nb_samples, ...params shape....]
    # so number of params is nubmer of elements in params shape
    nb_params = torch.numel(params[0])
    
    # the dimensions to sum are all but the first dim
    dims_to_sum = tuple(range(1, params.dim()))
    
    # normalize by number of parameters
    return torch.sum(params ** 2, dim=dims_to_sum) / nb_params 

def gradient_descent_for_dummy(param_to_loss):
    param_shape = [4,4]
    param_scale = 5
    param = ESParameter(para_means=torch.rand(param_shape).to(device) * param_scale, para_std=0.3, Optimizer=optim.Adam)
    
    
    average_loss_cross_samples = []
    for _ in range(5000):
        param_samples = param.sample(sample_size=30)        
        
        # loss shape: [nb_samples,]
        loss = param_to_loss(param_samples)
        
        param.gradient_descent(loss)
        average_loss_cross_samples.append(torch.mean(param.means).cpu())   
    
    plt.plot(average_loss_cross_samples, label='average loss cross samples')
    plt.xlabel('iterations')
    plt.ylabel('loss')
    plt.title('Gradient Descent on Quadratic Loss')
    plt.legend()
    plt.show()
    
gradient_descent_for_dummy(quadratic_landscape)

# %% [markdown]
# ## 2. ES on CNN on MNIST

# %%
from EvolutionStrategy import ESModel

import torch
from torchvision import datasets
from torchvision.transforms import ToTensor, Compose, Normalize
import torch.nn.functional as F
from torch import nn
import torch.optim as optim

device = 'cuda'

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2(x), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
from sklearn.model_selection import train_test_split
import wandb
import os

def _run_snn_on_batch(model, x, y, loss_fn): 
    pred = model(x)
    
    loss = loss_fn(pred, y)
    correct = (pred.argmax(1) == y).type(torch.float).sum().item()
    
    return loss, correct

def log_model(es_model,run):
    filename = 'best-model.pth'
    model = es_model.get_best_model()
    torch.save(model.state_dict(), filename)
    run.log_model(path=filename)
    os.remove(filename)  

def val_loop_snn(es_model, dataloader, loss_fn):
    model = es_model.get_best_model()
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    for x, y in dataloader:
        x, y = x.to(device), y.to(device)
        batch_loss, batch_correct = _run_snn_on_batch(model, x, y, loss_fn) 
        test_loss += batch_loss
        correct += batch_correct

    test_loss /= num_batches
    test_acc = correct / size
    print(f"Test Error: \nAccuracy: {(100*test_acc):>0.1f}%, Avg loss: {test_loss:>8f} \n")
        
    return test_loss.item(), test_acc

def train_loop_snn(es_model, train_dataloader, val_dataloader, loss_fn, nb_model_samples, run):
    """ one epoch of training, going through all the batches once
    """    
    for batch, (x, y) in enumerate(train_dataloader):
        x, y = x.to(device), y.to(device)
        # train model with samples
        samples_loss = []
        for model in es_model.samples(nb_model_samples):
            loss, _ = _run_snn_on_batch(model, x, y, loss_fn)
            samples_loss.append(loss)            
            
        samples_loss = torch.stack(samples_loss) 
        es_model.gradient_descent(samples_loss)
    
        # best model loss and accuracy
        best_model = es_model.get_best_model()
        best_loss, best_correct = _run_snn_on_batch(best_model, x, y, loss_fn)   
        best_acc = best_correct / len(y)
        print(f"batch {batch}, loss: {best_loss:>7f}, accuracy: {100 * best_acc:>0.1f}%")
        
        # validation loss and accuracy
        val_loss, val_acc = val_loop_snn(es_model, val_dataloader, loss_fn)
        
        # record keeping
        run.log({'train_loss': best_loss.item(), 'train_acc' : best_acc, 'val_loss': val_loss, 'val_acc': val_acc}) 
        # log_model(es_model, run)

# %%
def train_snn():   
    run_name = 'first-attempt'
    config = {'nb_model_samples': 1000,
              'std': 0.05,
              'lr': 0.01,
              'epochs': 25}
    with torch.no_grad(), wandb.init(entity = 'DarwinNeuron', project = 'ES-CNN-MNIST', name=run_name, config=config) as run:  
        train_dataloader = torch.utils.data.DataLoader(
            datasets.MNIST('data', train=True, download=True,
                                transform=Compose([
                                ToTensor(),
                                Normalize((0.1307,), (0.3081,))
                                ])),
            batch_size=256, shuffle=True)

        val_dataloader = torch.utils.data.DataLoader(
            datasets.MNIST('data', train=False, download=True,
                                        transform=Compose([
                                        ToTensor(),
                                        Normalize((0.1307,), (0.3081,))
                                        ])),
            batch_size=1000, shuffle=True)     
        es_model = ESModel(CNN, param_std = run.config.std, Optimizer=optim.Adam, lr=run.config.lr)
        for epoch in range(run.config.epochs):
            print(f"Epoch {epoch}\n-------------------------------")
            # train the model
            train_loop_snn(es_model,train_dataloader, val_dataloader, cross_entropy, run.config.nb_model_samples, run)
    
train_snn()
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: yixing to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/home/wyx/darwin_neuron/wandb/run-20250411_140520-nv59mf4t</code>
# Syncing run <strong><a href='https://wandb.ai/DarwinNeuron/ES-CNN-MNIST/runs/nv59mf4t' target="_blank">first-attempt</a></strong> to <a href='https://wandb.ai/DarwinNeuron/ES-CNN-MNIST' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/DarwinNeuron/ES-CNN-MNIST' target="_blank">https://wandb.ai/DarwinNeuron/ES-CNN-MNIST</a>
#  View run at <a href='https://wandb.ai/DarwinNeuron/ES-CNN-MNIST/runs/nv59mf4t' target="_blank">https://wandb.ai/DarwinNeuron/ES-CNN-MNIST/runs/nv59mf4t</a>
# Epoch 0
# -------------------------------
# batch 0, loss: 2.321057, accuracy: 11.3%
# Test Error:
# Accuracy: 11.3%, Avg loss: 2.319351
#
# batch 1, loss: 2.323903, accuracy: 10.2%
# Test Error:
# Accuracy: 11.3%, Avg loss: 2.319230
#
# batch 2, loss: 2.318732, accuracy: 11.7%
# Test Error:
# Accuracy: 11.3%, Avg loss: 2.320920
#
# batch 3, loss: 2.321547, accuracy: 10.5%
# Test Error:
# Accuracy: 11.4%, Avg loss: 2.322474
#
# batch 4, loss: 2.314988, accuracy: 9.8%
# Test Error:
# Accuracy: 9.3%, Avg loss: 2.324321
#
# batch 5, loss: 2.341904, accuracy: 9.4%
# Test Error:
# Accuracy: 7.8%, Avg loss: 2.326103
#
# batch 6, loss: 2.334600, accuracy: 7.0%
# Test Error:
# Accuracy: 8.5%, Avg loss: 2.327410
#
# batch 7, loss: 2.312607, accuracy: 10.2%
# Test Error:
# Accuracy: 9.2%, Avg loss: 2.329340
#
# batch 8, loss: 2.339482, accuracy: 8.6%
# Test Error:
# Accuracy: 9.5%, Avg loss: 2.330334
#
# batch 9, loss: 2.344823, accuracy: 9.4%
# Test Error:
# Accuracy: 9.6%, Avg loss: 2.331204
#
# batch 10, loss: 2.326989, accuracy: 13.7%
# Test Error:
# Accuracy: 9.8%, Avg loss: 2.331685
#
# batch 11, loss: 2.332278, accuracy: 9.4%
# Test Error:
# Accuracy: 9.9%, Avg loss: 2.332976
#
# batch 12, loss: 2.309419, accuracy: 12.9%
# Test Error:
# Accuracy: 9.8%, Avg loss: 2.334258
#
# batch 13, loss: 2.354815, accuracy: 7.8%
# Test Error:
# Accuracy: 9.8%, Avg loss: 2.333840
#
# batch 14, loss: 2.324713, accuracy: 10.9%
# Test Error:
# Accuracy: 9.7%, Avg loss: 2.332028
#
# batch 15, loss: 2.322854, accuracy: 9.4%
# Test Error:
# Accuracy: 9.7%, Avg loss: 2.330911
#
# batch 16, loss: 2.332634, accuracy: 8.6%
# Test Error:
# Accuracy: 9.4%, Avg loss: 2.330790
#
# batch 17, loss: 2.324623, accuracy: 8.6%
# Test Error:
# Accuracy: 9.3%, Avg loss: 2.331429
#
# batch 18, loss: 2.346582, accuracy: 7.8%
# Test Error:
# Accuracy: 9.2%, Avg loss: 2.330343
#
# batch 19, loss: 2.314722, accuracy: 9.0%
# Test Error:
# Accuracy: 9.3%, Avg loss: 2.328707
#
# batch 20, loss: 2.338566, accuracy: 9.8%
# Test Error:
# Accuracy: 9.2%, Avg loss: 2.326844
#
# batch 21, loss: 2.314998, accuracy: 11.3%
# Test Error:
# Accuracy: 9.1%, Avg loss: 2.326169
#
# batch 22, loss: 2.327321, accuracy: 8.2%
# Test Error:
# Accuracy: 9.0%, Avg loss: 2.325204
#
# batch 23, loss: 2.332499, accuracy: 8.6%
# Test Error:
# Accuracy: 8.6%, Avg loss: 2.323339
#
# batch 24, loss: 2.331329, accuracy: 7.8%
# Test Error:
# Accuracy: 8.4%, Avg loss: 2.321815
#
# batch 25, loss: 2.322838, accuracy: 7.0%
# Test Error:
# Accuracy: 8.0%, Avg loss: 2.321490
#
# batch 26, loss: 2.322028, accuracy: 7.0%
# Test Error:
# Accuracy: 7.8%, Avg loss: 2.322142
#
# batch 27, loss: 2.330610, accuracy: 6.6%
# Test Error:
# Accuracy: 7.9%, Avg loss: 2.323785
#
# batch 28, loss: 2.337488, accuracy: 6.2%
# Test Error:
# Accuracy: 7.6%, Avg loss: 2.324903
#
# batch 29, loss: 2.318137, accuracy: 7.4%
# Test Error:
# Accuracy: 7.6%, Avg loss: 2.326607
#
# batch 30, loss: 2.322790, accuracy: 9.8%
# Test Error:
# Accuracy: 7.5%, Avg loss: 2.326891
#
# batch 31, loss: 2.320246, accuracy: 8.2%
# Test Error:
# Accuracy: 7.4%, Avg loss: 2.326972
#
# batch 32, loss: 2.323977, accuracy: 10.2%
# Test Error:
# Accuracy: 7.2%, Avg loss: 2.328468
#
# batch 33, loss: 2.319075, accuracy: 9.0%
# Test Error:
# Accuracy: 7.2%, Avg loss: 2.330315
#
# batch 34, loss: 2.348401, accuracy: 4.3%
# Test Error:
# Accuracy: 7.0%, Avg loss: 2.331034
#
# batch 35, loss: 2.316798, accuracy: 5.1%
# Test Error:
# Accuracy: 6.8%, Avg loss: 2.330907
#
# batch 36, loss: 2.338720, accuracy: 5.5%
# Test Error:
# Accuracy: 6.8%, Avg loss: 2.330819
#
# batch 37, loss: 2.345495, accuracy: 6.2%
# Test Error:
# Accuracy: 6.9%, Avg loss: 2.330293
#
# batch 38, loss: 2.340800, accuracy: 8.2%
# Test Error:
# Accuracy: 7.2%, Avg loss: 2.328144
#
# batch 39, loss: 2.308423, accuracy: 9.8%
# Test Error:
# Accuracy: 7.5%, Avg loss: 2.322554
#
# batch 40, loss: 2.347739, accuracy: 5.1%
# Test Error:
# Accuracy: 7.8%, Avg loss: 2.318491
#
# batch 41, loss: 2.266021, accuracy: 10.2%
# Test Error:
# Accuracy: 8.1%, Avg loss: 2.314314
#
# batch 42, loss: 2.303251, accuracy: 7.8%
# Test Error:
# Accuracy: 8.6%, Avg loss: 2.308318
#
# batch 43, loss: 2.310136, accuracy: 8.6%
# Test Error:
# Accuracy: 9.1%, Avg loss: 2.304100
#
# batch 44, loss: 2.313850, accuracy: 9.8%
# Test Error:
# Accuracy: 9.4%, Avg loss: 2.301028
#
# batch 45, loss: 2.316388, accuracy: 10.2%
# Test Error:
# Accuracy: 9.9%, Avg loss: 2.298515
#
# batch 46, loss: 2.308516, accuracy: 9.4%
# Test Error:
# Accuracy: 10.4%, Avg loss: 2.296825
#
# batch 47, loss: 2.289907, accuracy: 11.3%
# Test Error:
# Accuracy: 11.2%, Avg loss: 2.291496
#
# batch 48, loss: 2.291930, accuracy: 9.4%
# Test Error:
# Accuracy: 11.9%, Avg loss: 2.284706
#
# batch 49, loss: 2.275595, accuracy: 10.2%
# Test Error:
# Accuracy: 12.5%, Avg loss: 2.275804
#
# batch 50, loss: 2.265975, accuracy: 14.1%
# Test Error:
# Accuracy: 13.3%, Avg loss: 2.268541
#
# batch 51, loss: 2.278166, accuracy: 10.9%
# Test Error:
# Accuracy: 13.8%, Avg loss: 2.262153
#
# batch 52, loss: 2.237315, accuracy: 16.4%
# Test Error:
# Accuracy: 14.3%, Avg loss: 2.255902
#
# batch 53, loss: 2.252937, accuracy: 16.8%
# Test Error:
# Accuracy: 14.7%, Avg loss: 2.251242
#
# batch 54, loss: 2.241907, accuracy: 12.9%
# Test Error:
# Accuracy: 14.8%, Avg loss: 2.248233
#
# batch 55, loss: 2.237214, accuracy: 13.3%
# Test Error:
# Accuracy: 15.3%, Avg loss: 2.245153
#
# batch 56, loss: 2.250053, accuracy: 13.3%
# Test Error:
# Accuracy: 15.6%, Avg loss: 2.242056
#
# batch 57, loss: 2.250513, accuracy: 13.7%
# Test Error:
# Accuracy: 15.9%, Avg loss: 2.237290
#
# batch 58, loss: 2.203119, accuracy: 19.5%
# Test Error:
# Accuracy: 16.6%, Avg loss: 2.233214
#
# batch 59, loss: 2.234388, accuracy: 15.6%
# Test Error:
# Accuracy: 16.7%, Avg loss: 2.230678
#
# batch 60, loss: 2.262274, accuracy: 13.3%
# Test Error:
# Accuracy: 16.9%, Avg loss: 2.228250
#
# batch 61, loss: 2.246071, accuracy: 14.8%
# Test Error:
# Accuracy: 17.1%, Avg loss: 2.225055
#
# batch 62, loss: 2.248976, accuracy: 15.2%
# Test Error:
# Accuracy: 17.4%, Avg loss: 2.222250
#
# batch 63, loss: 2.242017, accuracy: 14.1%
# Test Error:
# Accuracy: 17.6%, Avg loss: 2.217129
#
# batch 64, loss: 2.166141, accuracy: 21.5%
# Test Error:
# Accuracy: 17.9%, Avg loss: 2.210437
#
# batch 65, loss: 2.215773, accuracy: 20.7%
# Test Error:
# Accuracy: 17.6%, Avg loss: 2.207832
#
# batch 66, loss: 2.216285, accuracy: 20.3%
# Test Error:
# Accuracy: 17.5%, Avg loss: 2.205489
#
# batch 67, loss: 2.192935, accuracy: 17.2%
# Test Error:
# Accuracy: 17.4%, Avg loss: 2.201786
#
# batch 68, loss: 2.250523, accuracy: 12.5%
# Test Error:
# Accuracy: 17.8%, Avg loss: 2.198202
#
# batch 69, loss: 2.183407, accuracy: 19.9%
# Test Error:
# Accuracy: 18.0%, Avg loss: 2.193712
#
# batch 70, loss: 2.211398, accuracy: 15.2%
# Test Error:
# Accuracy: 18.3%, Avg loss: 2.189550
#
# batch 71, loss: 2.166108, accuracy: 19.9%
# Test Error:
# Accuracy: 18.7%, Avg loss: 2.185117
#
# batch 72, loss: 2.208972, accuracy: 20.3%
# Test Error:
# Accuracy: 19.0%, Avg loss: 2.182261
#
# batch 73, loss: 2.200345, accuracy: 16.4%
# Test Error:
# Accuracy: 19.4%, Avg loss: 2.178358
#
# batch 74, loss: 2.168800, accuracy: 17.6%
# Test Error:
# Accuracy: 19.6%, Avg loss: 2.174422
#
# batch 75, loss: 2.161002, accuracy: 22.3%
# Test Error:
# Accuracy: 20.1%, Avg loss: 2.169672
#
# batch 76, loss: 2.188124, accuracy: 19.1%
# Test Error:
# Accuracy: 20.5%, Avg loss: 2.164809
#
# batch 77, loss: 2.163419, accuracy: 22.3%
# Test Error:
# Accuracy: 20.9%, Avg loss: 2.159479
#
# batch 78, loss: 2.188359, accuracy: 16.8%
# Test Error:
# Accuracy: 21.3%, Avg loss: 2.153780
#
# batch 79, loss: 2.156142, accuracy: 23.4%
# Test Error:
# Accuracy: 21.7%, Avg loss: 2.149000
#
# batch 80, loss: 2.156890, accuracy: 21.9%
# Test Error:
# Accuracy: 22.6%, Avg loss: 2.143143
#
# batch 81, loss: 2.136241, accuracy: 21.5%
# Test Error:
# Accuracy: 23.4%, Avg loss: 2.138338
#
# batch 82, loss: 2.112571, accuracy: 25.0%
# Test Error:
# Accuracy: 23.8%, Avg loss: 2.134749
#
# batch 83, loss: 2.126617, accuracy: 25.4%
# Test Error:
# Accuracy: 23.7%, Avg loss: 2.133128
#
# batch 84, loss: 2.140669, accuracy: 21.5%
# Test Error:
# Accuracy: 23.5%, Avg loss: 2.133446
#
# batch 85, loss: 2.115488, accuracy: 24.2%
# Test Error:
# Accuracy: 23.4%, Avg loss: 2.134365
#
# batch 86, loss: 2.152234, accuracy: 21.1%
# Test Error:
# Accuracy: 22.9%, Avg loss: 2.135429
#
# batch 87, loss: 2.179448, accuracy: 21.5%
# Test Error:
# Accuracy: 22.6%, Avg loss: 2.136041
#
# batch 88, loss: 2.131624, accuracy: 21.5%
# Test Error:
# Accuracy: 22.2%, Avg loss: 2.137910
#
# batch 89, loss: 2.204856, accuracy: 18.4%
# Test Error:
# Accuracy: 22.1%, Avg loss: 2.139802
#
# batch 90, loss: 2.141951, accuracy: 19.9%
# Test Error:
# Accuracy: 22.2%, Avg loss: 2.140449
#
# batch 91, loss: 2.160499, accuracy: 20.3%
# Test Error:
# Accuracy: 22.4%, Avg loss: 2.136921
#
# batch 92, loss: 2.138011, accuracy: 23.8%
# Test Error:
# Accuracy: 22.8%, Avg loss: 2.131259
#
# batch 93, loss: 2.137079, accuracy: 22.3%
# Test Error:
# Accuracy: 23.5%, Avg loss: 2.123228
#
# batch 94, loss: 2.157543, accuracy: 23.8%
# Test Error:
# Accuracy: 24.4%, Avg loss: 2.115880
#
# batch 95, loss: 2.131195, accuracy: 22.7%
# Test Error:
# Accuracy: 25.1%, Avg loss: 2.108657
#
# batch 96, loss: 2.214584, accuracy: 20.7%
# Test Error:
# Accuracy: 26.0%, Avg loss: 2.100994
#
# batch 97, loss: 2.154586, accuracy: 25.8%
# Test Error:
# Accuracy: 26.6%, Avg loss: 2.094516
#
# batch 98, loss: 2.119241, accuracy: 20.3%
# Test Error:
# Accuracy: 26.9%, Avg loss: 2.088050
#
# batch 99, loss: 2.089221, accuracy: 28.1%
# Test Error:
# Accuracy: 27.2%, Avg loss: 2.080898
#
# batch 100, loss: 2.084492, accuracy: 24.6%
# Test Error:
# Accuracy: 27.5%, Avg loss: 2.073021
#
# batch 101, loss: 2.068707, accuracy: 27.0%
# Test Error:
# Accuracy: 27.8%, Avg loss: 2.067560
#
# batch 102, loss: 2.097806, accuracy: 25.8%
# Test Error:
# Accuracy: 27.8%, Avg loss: 2.063900
#
# batch 103, loss: 2.046291, accuracy: 26.2%
# Test Error:
# Accuracy: 27.8%, Avg loss: 2.060746
#
# batch 104, loss: 2.100055, accuracy: 24.6%
# Test Error:
# Accuracy: 28.3%, Avg loss: 2.056744
#
# batch 105, loss: 2.147363, accuracy: 25.4%
# Test Error:
# Accuracy: 28.6%, Avg loss: 2.051833
#
# batch 106, loss: 2.071997, accuracy: 25.4%
# Test Error:
# Accuracy: 28.9%, Avg loss: 2.045771
#
# batch 107, loss: 2.036466, accuracy: 28.5%
# Test Error:
# Accuracy: 29.5%, Avg loss: 2.037215
#
# batch 108, loss: 2.047527, accuracy: 27.7%
# Test Error:
# Accuracy: 30.1%, Avg loss: 2.027270
#
# batch 109, loss: 2.079332, accuracy: 26.6%
# Test Error:
# Accuracy: 30.4%, Avg loss: 2.018721
#
# batch 110, loss: 2.029027, accuracy: 30.1%
# Test Error:
# Accuracy: 30.8%, Avg loss: 2.010142
#
# batch 111, loss: 2.055558, accuracy: 27.7%
# Test Error:
# Accuracy: 31.0%, Avg loss: 2.001120
#
# batch 112, loss: 2.042460, accuracy: 24.6%
# Test Error:
# Accuracy: 31.4%, Avg loss: 1.992607
#
# batch 113, loss: 1.999828, accuracy: 30.1%
# Test Error:
# Accuracy: 31.4%, Avg loss: 1.985058
#
# batch 114, loss: 2.001493, accuracy: 29.3%
# Test Error:
# Accuracy: 31.8%, Avg loss: 1.977199
#
# batch 115, loss: 2.012267, accuracy: 30.1%
# Test Error:
# Accuracy: 31.9%, Avg loss: 1.970676
#
# batch 116, loss: 1.989032, accuracy: 30.5%
# Test Error:
# Accuracy: 31.9%, Avg loss: 1.964843
#
# batch 117, loss: 1.958573, accuracy: 31.6%
# Test Error:
# Accuracy: 31.9%, Avg loss: 1.959167
#
# batch 118, loss: 1.999698, accuracy: 31.2%
# Test Error:
# Accuracy: 32.3%, Avg loss: 1.954908
#
# batch 119, loss: 1.891704, accuracy: 37.5%
# Test Error:
# Accuracy: 32.4%, Avg loss: 1.950053
#
# batch 120, loss: 1.972217, accuracy: 29.3%
# Test Error:
# Accuracy: 32.6%, Avg loss: 1.945265
#
# batch 121, loss: 1.969054, accuracy: 30.9%
# Test Error:
# Accuracy: 32.5%, Avg loss: 1.941637
#
# batch 122, loss: 1.900268, accuracy: 32.8%
# Test Error:
# Accuracy: 32.5%, Avg loss: 1.938785
#
# batch 123, loss: 1.897702, accuracy: 37.5%
# Test Error:
# Accuracy: 32.6%, Avg loss: 1.934982
#
# batch 124, loss: 1.876462, accuracy: 36.3%
# Test Error:
# Accuracy: 32.9%, Avg loss: 1.930875
#
# batch 125, loss: 1.999470, accuracy: 26.2%
# Test Error:
# Accuracy: 33.2%, Avg loss: 1.924367
#
# batch 126, loss: 1.986420, accuracy: 28.5%
# Test Error:
# Accuracy: 33.2%, Avg loss: 1.917060
#
# batch 127, loss: 1.978222, accuracy: 29.3%
# Test Error:
# Accuracy: 33.2%, Avg loss: 1.911981
#
# batch 128, loss: 1.914678, accuracy: 32.4%
# Test Error:
# Accuracy: 33.3%, Avg loss: 1.908687
#
# batch 129, loss: 1.941782, accuracy: 33.2%
# Test Error:
# Accuracy: 33.6%, Avg loss: 1.908564
#
# batch 130, loss: 1.948208, accuracy: 29.3%
# Test Error:
# Accuracy: 33.4%, Avg loss: 1.909668
#
# batch 131, loss: 1.872946, accuracy: 35.2%
# Test Error:
# Accuracy: 33.5%, Avg loss: 1.911025
#
# batch 132, loss: 1.963796, accuracy: 30.1%
# Test Error:
# Accuracy: 33.7%, Avg loss: 1.911759
#
# batch 133, loss: 1.871725, accuracy: 36.7%
# Test Error:
# Accuracy: 33.8%, Avg loss: 1.909942
#
# batch 134, loss: 1.912891, accuracy: 31.2%
# Test Error:
# Accuracy: 33.7%, Avg loss: 1.909756
#
# batch 135, loss: 1.890233, accuracy: 32.8%
# Test Error:
# Accuracy: 34.0%, Avg loss: 1.908280
#
# batch 136, loss: 1.942145, accuracy: 33.2%
# Test Error:
# Accuracy: 33.8%, Avg loss: 1.907650
#
# batch 137, loss: 1.945172, accuracy: 30.9%
# Test Error:
# Accuracy: 33.6%, Avg loss: 1.908015
#
# batch 138, loss: 1.895319, accuracy: 35.2%
# Test Error:
# Accuracy: 33.4%, Avg loss: 1.908588
#
# batch 139, loss: 1.881393, accuracy: 35.2%
# Test Error:
# Accuracy: 33.1%, Avg loss: 1.909839
#
# batch 140, loss: 1.950445, accuracy: 28.9%
# Test Error:
# Accuracy: 33.0%, Avg loss: 1.912027
#
# batch 141, loss: 1.950815, accuracy: 34.0%
# Test Error:
# Accuracy: 32.6%, Avg loss: 1.916038
#
# batch 142, loss: 1.857509, accuracy: 35.2%
# Test Error:
# Accuracy: 32.6%, Avg loss: 1.919462
#
# batch 143, loss: 1.996604, accuracy: 26.6%
# Test Error:
# Accuracy: 32.7%, Avg loss: 1.920397
#
# batch 144, loss: 1.969176, accuracy: 27.3%
# Test Error:
# Accuracy: 32.4%, Avg loss: 1.918813
#
# batch 145, loss: 1.913029, accuracy: 33.6%
# Test Error:
# Accuracy: 32.4%, Avg loss: 1.919207
#
# batch 146, loss: 1.914720, accuracy: 29.3%
# Test Error:
# Accuracy: 32.4%, Avg loss: 1.916892
#
# batch 147, loss: 1.920289, accuracy: 37.5%
# Test Error:
# Accuracy: 32.3%, Avg loss: 1.914599
#
# batch 148, loss: 1.930024, accuracy: 31.2%
# Test Error:
# Accuracy: 32.1%, Avg loss: 1.911386
#
# batch 149, loss: 1.873208, accuracy: 35.9%
# Test Error:
# Accuracy: 32.2%, Avg loss: 1.909663
#
# batch 150, loss: 1.897049, accuracy: 31.6%
# Test Error:
# Accuracy: 32.3%, Avg loss: 1.908793
#
# batch 151, loss: 1.865633, accuracy: 33.6%
# Test Error:
# Accuracy: 32.3%, Avg loss: 1.908447
#
# batch 152, loss: 1.917762, accuracy: 28.9%
# Test Error:
# Accuracy: 32.5%, Avg loss: 1.904197
#
# batch 153, loss: 1.946610, accuracy: 34.0%
# Test Error:
# Accuracy: 32.6%, Avg loss: 1.898797
#
# batch 154, loss: 1.880824, accuracy: 34.0%
# Test Error:
# Accuracy: 33.1%, Avg loss: 1.891710
#
# batch 155, loss: 1.923653, accuracy: 33.6%
# Test Error:
# Accuracy: 33.5%, Avg loss: 1.885164
#
# batch 156, loss: 1.997046, accuracy: 26.6%
# Test Error:
# Accuracy: 34.0%, Avg loss: 1.878674
#
# batch 157, loss: 1.838151, accuracy: 37.1%
# Test Error:
# Accuracy: 34.6%, Avg loss: 1.873435
#
# batch 158, loss: 1.854574, accuracy: 35.5%
# Test Error:
# Accuracy: 35.1%, Avg loss: 1.862504
#
# batch 159, loss: 1.861712, accuracy: 35.5%
# Test Error:
# Accuracy: 35.6%, Avg loss: 1.852084
#
# batch 160, loss: 1.930318, accuracy: 30.9%
# Test Error:
# Accuracy: 36.1%, Avg loss: 1.843816
#
# batch 161, loss: 1.865245, accuracy: 35.2%
# Test Error:
# Accuracy: 36.7%, Avg loss: 1.832082
#
# batch 162, loss: 1.830887, accuracy: 32.0%
# Test Error:
# Accuracy: 37.2%, Avg loss: 1.818447
#
# batch 163, loss: 1.839508, accuracy: 34.4%
# Test Error:
# Accuracy: 37.5%, Avg loss: 1.806956
#
# batch 164, loss: 1.832012, accuracy: 33.2%
# Test Error:
# Accuracy: 37.4%, Avg loss: 1.798589
#
# batch 165, loss: 1.794673, accuracy: 37.9%
# Test Error:
# Accuracy: 37.4%, Avg loss: 1.792763
#
# batch 166, loss: 1.810246, accuracy: 33.6%
# Test Error:
# Accuracy: 37.3%, Avg loss: 1.790034
#
# batch 167, loss: 1.804708, accuracy: 39.8%
# Test Error:
# Accuracy: 37.4%, Avg loss: 1.786782
#
# batch 168, loss: 1.698249, accuracy: 43.0%
# Test Error:
# Accuracy: 37.3%, Avg loss: 1.783048
#
# batch 169, loss: 1.771328, accuracy: 38.3%
# Test Error:
# Accuracy: 37.1%, Avg loss: 1.780229
#
# batch 170, loss: 1.783726, accuracy: 38.3%
# Test Error:
# Accuracy: 37.3%, Avg loss: 1.775769
#
# batch 171, loss: 1.830831, accuracy: 37.9%
# Test Error:
# Accuracy: 37.4%, Avg loss: 1.772647
#
# batch 172, loss: 1.762499, accuracy: 35.5%
# Test Error:
# Accuracy: 38.0%, Avg loss: 1.768363
#
# batch 173, loss: 1.793171, accuracy: 38.3%
# Test Error:
# Accuracy: 38.5%, Avg loss: 1.765670
#
# batch 174, loss: 1.767608, accuracy: 39.1%
# Test Error:
# Accuracy: 39.0%, Avg loss: 1.761475
#
# batch 175, loss: 1.882251, accuracy: 32.0%
# Test Error:
# Accuracy: 39.2%, Avg loss: 1.756468
#
# batch 176, loss: 1.718349, accuracy: 40.2%
# Test Error:
# Accuracy: 39.6%, Avg loss: 1.751799
#
# batch 177, loss: 1.743550, accuracy: 44.1%
# Test Error:
# Accuracy: 39.9%, Avg loss: 1.744087
#
# batch 178, loss: 1.787038, accuracy: 38.3%
# Test Error:
# Accuracy: 40.2%, Avg loss: 1.737382
#
# batch 179, loss: 1.730610, accuracy: 41.4%
# Test Error:
# Accuracy: 40.4%, Avg loss: 1.733318
#
# batch 180, loss: 1.614121, accuracy: 44.9%
# Test Error:
# Accuracy: 40.4%, Avg loss: 1.731867
#
# batch 181, loss: 1.769674, accuracy: 41.0%
# Test Error:
# Accuracy: 40.4%, Avg loss: 1.728918
#
# batch 182, loss: 1.752695, accuracy: 39.5%
# Test Error:
# Accuracy: 40.6%, Avg loss: 1.725276
#
# batch 183, loss: 1.683703, accuracy: 41.8%
# Test Error:
# Accuracy: 40.6%, Avg loss: 1.722525
#
# batch 184, loss: 1.768787, accuracy: 35.2%
# Test Error:
# Accuracy: 40.5%, Avg loss: 1.719081
#
# batch 185, loss: 1.807233, accuracy: 35.9%
# Test Error:
# Accuracy: 40.5%, Avg loss: 1.716317
#
# batch 186, loss: 1.758692, accuracy: 37.5%
# Test Error:
# Accuracy: 40.5%, Avg loss: 1.715038
#
# batch 187, loss: 1.675904, accuracy: 42.2%
# Test Error:
# Accuracy: 40.3%, Avg loss: 1.716021
#
# batch 188, loss: 1.740342, accuracy: 42.2%
# Test Error:
# Accuracy: 40.0%, Avg loss: 1.718462
#
# batch 189, loss: 1.713489, accuracy: 40.2%
# Test Error:
# Accuracy: 39.8%, Avg loss: 1.722385
#
# batch 190, loss: 1.761829, accuracy: 39.5%
# Test Error:
# Accuracy: 39.6%, Avg loss: 1.723601
#
# batch 191, loss: 1.736433, accuracy: 34.8%
# Test Error:
# Accuracy: 39.8%, Avg loss: 1.723637
#
# batch 192, loss: 1.584165, accuracy: 44.9%
# Test Error:
# Accuracy: 39.6%, Avg loss: 1.723322
#
# batch 193, loss: 1.776815, accuracy: 39.1%
# Test Error:
# Accuracy: 39.8%, Avg loss: 1.722678
#
# batch 194, loss: 1.835237, accuracy: 34.4%
# Test Error:
# Accuracy: 39.8%, Avg loss: 1.721702
#
# batch 195, loss: 1.777210, accuracy: 34.4%
# Test Error:
# Accuracy: 40.1%, Avg loss: 1.716836
#
# batch 196, loss: 1.796579, accuracy: 39.1%
# Test Error:
# Accuracy: 40.5%, Avg loss: 1.710135
#
# batch 197, loss: 1.689367, accuracy: 42.2%
# Test Error:
# Accuracy: 41.0%, Avg loss: 1.701499
#
# batch 198, loss: 1.651345, accuracy: 41.8%
# Test Error:
# Accuracy: 41.3%, Avg loss: 1.692981
#
# batch 199, loss: 1.721958, accuracy: 41.4%
# Test Error:
# Accuracy: 42.0%, Avg loss: 1.682246
#
# batch 200, loss: 1.740839, accuracy: 39.5%
# Test Error:
# Accuracy: 42.6%, Avg loss: 1.670632
#
# batch 201, loss: 1.755417, accuracy: 37.9%
# Test Error:
# Accuracy: 43.3%, Avg loss: 1.660357
#
# batch 202, loss: 1.633264, accuracy: 44.5%
# Test Error:
# Accuracy: 44.1%, Avg loss: 1.650333
#
# batch 203, loss: 1.618025, accuracy: 46.1%
# Test Error:
# Accuracy: 44.7%, Avg loss: 1.641999
#
# batch 204, loss: 1.589308, accuracy: 50.0%
# Test Error:
# Accuracy: 45.1%, Avg loss: 1.636596
#
# batch 205, loss: 1.646928, accuracy: 47.3%
# Test Error:
# Accuracy: 45.8%, Avg loss: 1.631948
#
# batch 206, loss: 1.487722, accuracy: 48.8%
# Test Error:
# Accuracy: 46.2%, Avg loss: 1.628353
#
# batch 207, loss: 1.641284, accuracy: 46.9%
# Test Error:
# Accuracy: 46.4%, Avg loss: 1.623720
#
# batch 208, loss: 1.607880, accuracy: 44.9%
# Test Error:
# Accuracy: 46.7%, Avg loss: 1.617160
#
# batch 209, loss: 1.728788, accuracy: 42.2%
# Test Error:
# Accuracy: 46.8%, Avg loss: 1.612417
#
# batch 210, loss: 1.588456, accuracy: 47.7%
# Test Error:
# Accuracy: 47.3%, Avg loss: 1.605842
#
# batch 211, loss: 1.612423, accuracy: 47.7%
# Test Error:
# Accuracy: 47.5%, Avg loss: 1.602084
#
# batch 212, loss: 1.710876, accuracy: 42.6%
# Test Error:
# Accuracy: 47.6%, Avg loss: 1.598919
#
# batch 213, loss: 1.621835, accuracy: 47.7%
# Test Error:
# Accuracy: 47.4%, Avg loss: 1.596561
#
# batch 214, loss: 1.482343, accuracy: 50.8%
# Test Error:
# Accuracy: 47.6%, Avg loss: 1.594191
#
# batch 215, loss: 1.579815, accuracy: 51.6%
# Test Error:
# Accuracy: 47.5%, Avg loss: 1.591173
#
# batch 216, loss: 1.554063, accuracy: 52.7%
# Test Error:
# Accuracy: 47.4%, Avg loss: 1.589407
#
# batch 217, loss: 1.582674, accuracy: 51.6%
# Test Error:
# Accuracy: 47.5%, Avg loss: 1.587345
#
# batch 218, loss: 1.591849, accuracy: 46.9%
# Test Error:
# Accuracy: 47.4%, Avg loss: 1.586438
#
# batch 219, loss: 1.497278, accuracy: 48.0%
# Test Error:
# Accuracy: 47.2%, Avg loss: 1.587067
#
# batch 220, loss: 1.480274, accuracy: 53.1%
# Test Error:
# Accuracy: 47.1%, Avg loss: 1.589548
#
# batch 221, loss: 1.599946, accuracy: 48.8%
# Test Error:
# Accuracy: 47.0%, Avg loss: 1.592398
#
# batch 222, loss: 1.615618, accuracy: 44.9%
# Test Error:
# Accuracy: 46.7%, Avg loss: 1.596195
#
# batch 223, loss: 1.605581, accuracy: 46.1%
# Test Error:
# Accuracy: 46.4%, Avg loss: 1.600331
#
# batch 224, loss: 1.612450, accuracy: 45.7%
# Test Error:
# Accuracy: 46.1%, Avg loss: 1.604758
#
# batch 225, loss: 1.573286, accuracy: 44.5%
# Test Error:
# Accuracy: 45.6%, Avg loss: 1.608564
#
# batch 226, loss: 1.631325, accuracy: 45.7%
# Test Error:
# Accuracy: 45.4%, Avg loss: 1.610387
#
# batch 227, loss: 1.669137, accuracy: 44.9%
# Test Error:
# Accuracy: 45.4%, Avg loss: 1.609456
#
# batch 228, loss: 1.657356, accuracy: 42.2%
# Test Error:
# Accuracy: 45.6%, Avg loss: 1.606868
#
# batch 229, loss: 1.648242, accuracy: 42.6%
# Test Error:
# Accuracy: 45.6%, Avg loss: 1.605136
#
# batch 230, loss: 1.598750, accuracy: 45.7%
# Test Error:
# Accuracy: 45.6%, Avg loss: 1.602092
#
# batch 231, loss: 1.569292, accuracy: 47.7%
# Test Error:
# Accuracy: 45.8%, Avg loss: 1.595727
#
# batch 232, loss: 1.516316, accuracy: 46.5%
# Test Error:
# Accuracy: 46.0%, Avg loss: 1.591558
#
# batch 233, loss: 1.559765, accuracy: 48.0%
# Test Error:
# Accuracy: 46.0%, Avg loss: 1.589005
#
# batch 234, loss: 1.611906, accuracy: 49.0%
# Test Error:
# Accuracy: 46.2%, Avg loss: 1.587101
#
# Epoch 1
# -------------------------------
# batch 0, loss: 1.510727, accuracy: 49.6%
# Test Error:
# Accuracy: 46.2%, Avg loss: 1.583823
#
# batch 1, loss: 1.511410, accuracy: 52.7%
# Test Error:
# Accuracy: 46.3%, Avg loss: 1.579996
#
# batch 2, loss: 1.618229, accuracy: 47.3%
# Test Error:
# Accuracy: 46.5%, Avg loss: 1.574548
#
# batch 3, loss: 1.580775, accuracy: 47.3%
# Test Error:
# Accuracy: 47.0%, Avg loss: 1.566840
#
# batch 4, loss: 1.739967, accuracy: 45.3%
# Test Error:
# Accuracy: 47.2%, Avg loss: 1.564494
#
# batch 5, loss: 1.631040, accuracy: 45.7%
# Test Error:
# Accuracy: 47.4%, Avg loss: 1.561543
#
# batch 6, loss: 1.519542, accuracy: 48.8%
# Test Error:
# Accuracy: 47.5%, Avg loss: 1.557606
#
# batch 7, loss: 1.582804, accuracy: 45.3%
# Test Error:
# Accuracy: 47.6%, Avg loss: 1.547014
#
# batch 8, loss: 1.453587, accuracy: 52.0%
# Test Error:
# Accuracy: 47.8%, Avg loss: 1.538197
#
# batch 9, loss: 1.631654, accuracy: 44.9%
# Test Error:
# Accuracy: 48.3%, Avg loss: 1.524209
#
# batch 10, loss: 1.549258, accuracy: 47.3%
# Test Error:
# Accuracy: 48.9%, Avg loss: 1.509503
#
# batch 11, loss: 1.412563, accuracy: 50.8%
# Test Error:
# Accuracy: 49.5%, Avg loss: 1.493875
#
# batch 12, loss: 1.414237, accuracy: 54.3%
# Test Error:
# Accuracy: 50.1%, Avg loss: 1.478885
#
# batch 13, loss: 1.515501, accuracy: 50.4%
# Test Error:
# Accuracy: 50.4%, Avg loss: 1.461389
#
# batch 14, loss: 1.509396, accuracy: 46.5%
# Test Error:
# Accuracy: 50.6%, Avg loss: 1.447643
#
# batch 15, loss: 1.438819, accuracy: 51.2%
# Test Error:
# Accuracy: 50.5%, Avg loss: 1.440475
#
# batch 16, loss: 1.501175, accuracy: 48.4%
# Test Error:
# Accuracy: 50.5%, Avg loss: 1.435343
#
# batch 17, loss: 1.521321, accuracy: 47.3%
# Test Error:
# Accuracy: 50.3%, Avg loss: 1.432251
#
# batch 18, loss: 1.447269, accuracy: 44.1%
# Test Error:
# Accuracy: 50.2%, Avg loss: 1.431415
#
# batch 19, loss: 1.422961, accuracy: 50.4%
# Test Error:
# Accuracy: 49.8%, Avg loss: 1.432896
#
# batch 20, loss: 1.510398, accuracy: 43.4%
# Test Error:
# Accuracy: 49.5%, Avg loss: 1.438248
#
# batch 21, loss: 1.459749, accuracy: 47.7%
# Test Error:
# Accuracy: 49.1%, Avg loss: 1.443146
#
# batch 22, loss: 1.564720, accuracy: 45.3%
# Test Error:
# Accuracy: 48.8%, Avg loss: 1.448465
#
# batch 23, loss: 1.589249, accuracy: 46.5%
# Test Error:
# Accuracy: 48.6%, Avg loss: 1.453152
#
# batch 24, loss: 1.417254, accuracy: 51.2%
# Test Error:
# Accuracy: 48.5%, Avg loss: 1.455439
#
# batch 25, loss: 1.516381, accuracy: 49.6%
# Test Error:
# Accuracy: 48.3%, Avg loss: 1.458369
#
# batch 26, loss: 1.431071, accuracy: 48.0%
# Test Error:
# Accuracy: 48.3%, Avg loss: 1.458901
#
# batch 27, loss: 1.437325, accuracy: 48.4%
# Test Error:
# Accuracy: 48.5%, Avg loss: 1.458738
#
# batch 28, loss: 1.446328, accuracy: 47.3%
# Test Error:
# Accuracy: 48.6%, Avg loss: 1.460768
#
# batch 29, loss: 1.438813, accuracy: 47.7%
# Test Error:
# Accuracy: 48.8%, Avg loss: 1.461802
#
# batch 30, loss: 1.471565, accuracy: 50.4%
# Test Error:
# Accuracy: 49.0%, Avg loss: 1.459853
#
# batch 31, loss: 1.367091, accuracy: 53.1%
# Test Error:
# Accuracy: 49.1%, Avg loss: 1.457781
#
# batch 32, loss: 1.604161, accuracy: 43.8%
# Test Error:
# Accuracy: 49.3%, Avg loss: 1.454865
#
# batch 33, loss: 1.390785, accuracy: 52.3%
# Test Error:
# Accuracy: 49.3%, Avg loss: 1.451311
#
# batch 34, loss: 1.514667, accuracy: 44.9%
# Test Error:
# Accuracy: 49.4%, Avg loss: 1.448856
#
# batch 35, loss: 1.412798, accuracy: 48.4%
# Test Error:
# Accuracy: 49.5%, Avg loss: 1.446458
#
# batch 36, loss: 1.395618, accuracy: 51.2%
# Test Error:
# Accuracy: 49.7%, Avg loss: 1.442846
#
# batch 37, loss: 1.471295, accuracy: 48.4%
# Test Error:
# Accuracy: 50.0%, Avg loss: 1.439161
#
# batch 38, loss: 1.438947, accuracy: 49.6%
# Test Error:
# Accuracy: 50.1%, Avg loss: 1.436886
#
# batch 39, loss: 1.575086, accuracy: 45.7%
# Test Error:
# Accuracy: 50.1%, Avg loss: 1.434874
#
# batch 40, loss: 1.436468, accuracy: 52.0%
# Test Error:
# Accuracy: 50.3%, Avg loss: 1.431762
#
# batch 41, loss: 1.530141, accuracy: 43.8%
# Test Error:
# Accuracy: 50.5%, Avg loss: 1.429718
#
# batch 42, loss: 1.400910, accuracy: 50.0%
# Test Error:
# Accuracy: 50.4%, Avg loss: 1.427129
#
# batch 43, loss: 1.382472, accuracy: 54.7%
# Test Error:
# Accuracy: 50.5%, Avg loss: 1.422961
#
# batch 44, loss: 1.343394, accuracy: 54.7%
# Test Error:
# Accuracy: 50.8%, Avg loss: 1.416808
#
# batch 45, loss: 1.387477, accuracy: 54.3%
# Test Error:
# Accuracy: 50.9%, Avg loss: 1.413080
#
# batch 46, loss: 1.354870, accuracy: 53.1%
# Test Error:
# Accuracy: 51.1%, Avg loss: 1.409080
#
# batch 47, loss: 1.501916, accuracy: 44.5%
# Test Error:
# Accuracy: 51.3%, Avg loss: 1.404266
#
# batch 48, loss: 1.399888, accuracy: 54.7%
# Test Error:
# Accuracy: 51.7%, Avg loss: 1.398180
#
# batch 49, loss: 1.349782, accuracy: 56.6%
# Test Error:
# Accuracy: 51.9%, Avg loss: 1.390557
#
# batch 50, loss: 1.468256, accuracy: 48.4%
# Test Error:
# Accuracy: 52.0%, Avg loss: 1.384807
#
# batch 51, loss: 1.326229, accuracy: 52.7%
# Test Error:
# Accuracy: 52.2%, Avg loss: 1.379630
#
# batch 52, loss: 1.373215, accuracy: 54.7%
# Test Error:
# Accuracy: 52.5%, Avg loss: 1.372384
#
# batch 53, loss: 1.358169, accuracy: 52.3%
# Test Error:
# Accuracy: 52.8%, Avg loss: 1.366141
#
# batch 54, loss: 1.441312, accuracy: 47.7%
# Test Error:
# Accuracy: 52.9%, Avg loss: 1.361125
#
# batch 55, loss: 1.286168, accuracy: 55.9%
# Test Error:
# Accuracy: 52.9%, Avg loss: 1.357440
#
# batch 56, loss: 1.439734, accuracy: 49.6%
# Test Error:
# Accuracy: 52.8%, Avg loss: 1.355347
#
# batch 57, loss: 1.265732, accuracy: 58.2%
# Test Error:
# Accuracy: 52.7%, Avg loss: 1.355013
#
# batch 58, loss: 1.406890, accuracy: 48.8%
# Test Error:
# Accuracy: 52.9%, Avg loss: 1.354700
#
# batch 59, loss: 1.390711, accuracy: 47.7%
# Test Error:
# Accuracy: 52.9%, Avg loss: 1.355884
#
# batch 60, loss: 1.401198, accuracy: 48.8%
# Test Error:
# Accuracy: 52.8%, Avg loss: 1.357972
#
# batch 61, loss: 1.476096, accuracy: 46.1%
# Test Error:
# Accuracy: 52.7%, Avg loss: 1.356192
#
# batch 62, loss: 1.318723, accuracy: 53.1%
# Test Error:
# Accuracy: 52.8%, Avg loss: 1.354318
#
# batch 63, loss: 1.394149, accuracy: 51.6%
# Test Error:
# Accuracy: 53.1%, Avg loss: 1.348330
#
# batch 64, loss: 1.408326, accuracy: 49.2%
# Test Error:
# Accuracy: 53.3%, Avg loss: 1.342449
#
# batch 65, loss: 1.398847, accuracy: 50.0%
# Test Error:
# Accuracy: 53.6%, Avg loss: 1.335605
#
# batch 66, loss: 1.326023, accuracy: 53.9%
# Test Error:
# Accuracy: 54.0%, Avg loss: 1.329489
#
# batch 67, loss: 1.253464, accuracy: 56.2%
# Test Error:
# Accuracy: 54.1%, Avg loss: 1.325048
#
# batch 68, loss: 1.333671, accuracy: 52.7%
# Test Error:
# Accuracy: 54.1%, Avg loss: 1.323349
#
# batch 69, loss: 1.235583, accuracy: 58.2%
# Test Error:
# Accuracy: 53.9%, Avg loss: 1.322314
#
# batch 70, loss: 1.342777, accuracy: 49.2%
# Test Error:
# Accuracy: 54.2%, Avg loss: 1.320516
#
# batch 71, loss: 1.331360, accuracy: 52.7%
# Test Error:
# Accuracy: 54.2%, Avg loss: 1.317856
#
# batch 72, loss: 1.312767, accuracy: 53.1%
# Test Error:
# Accuracy: 54.4%, Avg loss: 1.315435
#
# batch 73, loss: 1.444485, accuracy: 52.0%
# Test Error:
# Accuracy: 54.7%, Avg loss: 1.313313
#
# batch 74, loss: 1.348394, accuracy: 52.7%
# Test Error:
# Accuracy: 54.9%, Avg loss: 1.310997
#
# batch 75, loss: 1.369111, accuracy: 52.0%
# Test Error:
# Accuracy: 54.9%, Avg loss: 1.308605
#
# batch 76, loss: 1.313834, accuracy: 55.1%
# Test Error:
# Accuracy: 55.3%, Avg loss: 1.303352
#
# batch 77, loss: 1.286750, accuracy: 58.6%
# Test Error:
# Accuracy: 55.5%, Avg loss: 1.296878
#
# batch 78, loss: 1.375596, accuracy: 52.3%
# Test Error:
# Accuracy: 55.6%, Avg loss: 1.292600
#
# batch 79, loss: 1.312960, accuracy: 54.3%
# Test Error:
# Accuracy: 55.8%, Avg loss: 1.289881
#
# batch 80, loss: 1.423262, accuracy: 51.6%
# Test Error:
# Accuracy: 56.0%, Avg loss: 1.285802
#
# batch 81, loss: 1.205483, accuracy: 58.6%
# Test Error:
# Accuracy: 56.1%, Avg loss: 1.282448
#
# batch 82, loss: 1.267981, accuracy: 56.6%
# Test Error:
# Accuracy: 56.2%, Avg loss: 1.279525
#
# batch 83, loss: 1.328973, accuracy: 56.6%
# Test Error:
# Accuracy: 56.4%, Avg loss: 1.278226
#
# batch 84, loss: 1.340654, accuracy: 55.9%
# Test Error:
# Accuracy: 56.1%, Avg loss: 1.279316
#
# batch 85, loss: 1.274842, accuracy: 55.1%
# Test Error:
# Accuracy: 56.2%, Avg loss: 1.279894
#
# batch 86, loss: 1.288245, accuracy: 54.3%
# Test Error:
# Accuracy: 56.2%, Avg loss: 1.280323
#
# batch 87, loss: 1.294424, accuracy: 58.6%
# Test Error:
# Accuracy: 56.2%, Avg loss: 1.279672
#
# batch 88, loss: 1.210243, accuracy: 57.8%
# Test Error:
# Accuracy: 56.5%, Avg loss: 1.278391
#
# batch 89, loss: 1.215608, accuracy: 59.0%
# Test Error:
# Accuracy: 56.8%, Avg loss: 1.277338
#
# batch 90, loss: 1.234275, accuracy: 61.3%
# Test Error:
# Accuracy: 56.9%, Avg loss: 1.277019
#
# batch 91, loss: 1.348237, accuracy: 50.4%
# Test Error:
# Accuracy: 57.0%, Avg loss: 1.273034
#
# batch 92, loss: 1.459144, accuracy: 52.0%
# Test Error:
# Accuracy: 57.0%, Avg loss: 1.267743
#
# batch 93, loss: 1.325063, accuracy: 54.7%
# Test Error:
# Accuracy: 57.1%, Avg loss: 1.259028
#
# batch 94, loss: 1.319955, accuracy: 53.9%
# Test Error:
# Accuracy: 57.2%, Avg loss: 1.251155
#
# batch 95, loss: 1.411630, accuracy: 52.0%
# Test Error:
# Accuracy: 57.4%, Avg loss: 1.242717
#
# batch 96, loss: 1.216164, accuracy: 54.7%
# Test Error:
# Accuracy: 57.7%, Avg loss: 1.234595
#
# batch 97, loss: 1.232058, accuracy: 57.0%
# Test Error:
# Accuracy: 58.1%, Avg loss: 1.226352
#
# batch 98, loss: 1.334712, accuracy: 55.5%
# Test Error:
# Accuracy: 58.3%, Avg loss: 1.219283
#
# batch 99, loss: 1.161469, accuracy: 61.7%
# Test Error:
# Accuracy: 58.3%, Avg loss: 1.214267
#
# batch 100, loss: 1.232925, accuracy: 56.2%
# Test Error:
# Accuracy: 58.4%, Avg loss: 1.210347
#
# batch 101, loss: 1.132948, accuracy: 60.9%
# Test Error:
# Accuracy: 58.4%, Avg loss: 1.207490
#
# batch 102, loss: 1.200442, accuracy: 58.6%
# Test Error:
# Accuracy: 58.3%, Avg loss: 1.206107
#
# batch 103, loss: 1.257536, accuracy: 55.9%
# Test Error:
# Accuracy: 58.5%, Avg loss: 1.204991
#
# batch 104, loss: 1.137278, accuracy: 62.9%
# Test Error:
# Accuracy: 58.5%, Avg loss: 1.206948
#
# batch 105, loss: 1.221955, accuracy: 60.2%
# Test Error:
# Accuracy: 58.3%, Avg loss: 1.210019
#
# batch 106, loss: 1.247213, accuracy: 58.6%
# Test Error:
# Accuracy: 58.4%, Avg loss: 1.210853
#
# batch 107, loss: 1.099463, accuracy: 62.9%
# Test Error:
# Accuracy: 58.5%, Avg loss: 1.211161
#
# batch 108, loss: 1.249131, accuracy: 55.9%
# Test Error:
# Accuracy: 58.5%, Avg loss: 1.211146
#
# batch 109, loss: 1.168183, accuracy: 61.7%
# Test Error:
# Accuracy: 58.6%, Avg loss: 1.212407
#
# batch 110, loss: 1.152147, accuracy: 59.4%
# Test Error:
# Accuracy: 58.6%, Avg loss: 1.212962
#
# batch 111, loss: 1.198444, accuracy: 59.4%
# Test Error:
# Accuracy: 58.7%, Avg loss: 1.214317
#
# batch 112, loss: 1.223601, accuracy: 56.6%
# Test Error:
# Accuracy: 58.7%, Avg loss: 1.215776
#
# batch 113, loss: 1.307287, accuracy: 52.0%
# Test Error:
# Accuracy: 58.7%, Avg loss: 1.215403
#
# batch 114, loss: 1.314980, accuracy: 53.9%
# Test Error:
# Accuracy: 58.7%, Avg loss: 1.215434
#
# batch 115, loss: 1.018449, accuracy: 66.0%
# Test Error:
# Accuracy: 58.6%, Avg loss: 1.215061
#
# batch 116, loss: 1.146581, accuracy: 58.2%
# Test Error:
# Accuracy: 58.8%, Avg loss: 1.213319
#
# batch 117, loss: 1.216846, accuracy: 60.9%
# Test Error:
# Accuracy: 58.9%, Avg loss: 1.212484
#
# batch 118, loss: 1.197271, accuracy: 57.0%
# Test Error:
# Accuracy: 58.9%, Avg loss: 1.211423
#
# batch 119, loss: 1.200451, accuracy: 60.2%
# Test Error:
# Accuracy: 59.0%, Avg loss: 1.210042
#
# batch 120, loss: 1.308744, accuracy: 57.8%
# Test Error:
# Accuracy: 59.1%, Avg loss: 1.207488
#
# batch 121, loss: 1.078068, accuracy: 65.6%
# Test Error:
# Accuracy: 59.2%, Avg loss: 1.202613
#
# batch 122, loss: 1.156298, accuracy: 58.6%
# Test Error:
# Accuracy: 59.6%, Avg loss: 1.198027
#
# batch 123, loss: 1.256119, accuracy: 58.2%
# Test Error:
# Accuracy: 59.7%, Avg loss: 1.194414
#
# batch 124, loss: 1.218238, accuracy: 58.2%
# Test Error:
# Accuracy: 59.7%, Avg loss: 1.190566
#
# batch 125, loss: 1.181265, accuracy: 62.5%
# Test Error:
# Accuracy: 60.0%, Avg loss: 1.185564
#
# batch 126, loss: 1.178518, accuracy: 58.2%
# Test Error:
# Accuracy: 60.1%, Avg loss: 1.182690
#
# batch 127, loss: 1.194980, accuracy: 60.5%
# Test Error:
# Accuracy: 60.3%, Avg loss: 1.179042
#
# batch 128, loss: 1.133104, accuracy: 62.1%
# Test Error:
# Accuracy: 60.3%, Avg loss: 1.175865
#
# batch 129, loss: 1.218588, accuracy: 59.4%
# Test Error:
# Accuracy: 60.5%, Avg loss: 1.170203
#
# batch 130, loss: 1.284673, accuracy: 58.6%
# Test Error:
# Accuracy: 60.7%, Avg loss: 1.166002
#
# batch 131, loss: 1.238207, accuracy: 57.8%
# Test Error:
# Accuracy: 60.7%, Avg loss: 1.162580
#
# batch 132, loss: 1.126688, accuracy: 61.3%
# Test Error:
# Accuracy: 60.9%, Avg loss: 1.158486
#
# batch 133, loss: 1.066773, accuracy: 64.8%
# Test Error:
# Accuracy: 61.0%, Avg loss: 1.153827
#
# batch 134, loss: 1.188108, accuracy: 59.4%
# Test Error:
# Accuracy: 61.1%, Avg loss: 1.149959
#
# batch 135, loss: 1.253778, accuracy: 59.8%
# Test Error:
# Accuracy: 61.3%, Avg loss: 1.147128
#
# batch 136, loss: 1.192710, accuracy: 59.0%
# Test Error:
# Accuracy: 61.3%, Avg loss: 1.142425
#
# batch 137, loss: 1.341975, accuracy: 53.1%
# Test Error:
# Accuracy: 61.4%, Avg loss: 1.138723
#
# batch 138, loss: 1.066103, accuracy: 65.6%
# Test Error:
# Accuracy: 61.5%, Avg loss: 1.137468
#
# batch 139, loss: 1.222284, accuracy: 57.8%
# Test Error:
# Accuracy: 61.7%, Avg loss: 1.135758
#
# batch 140, loss: 1.094051, accuracy: 63.3%
# Test Error:
# Accuracy: 61.7%, Avg loss: 1.135446
#
# batch 141, loss: 1.101687, accuracy: 61.3%
# Test Error:
# Accuracy: 61.7%, Avg loss: 1.136674
#
# batch 142, loss: 1.182142, accuracy: 62.5%
# Test Error:
# Accuracy: 61.7%, Avg loss: 1.137815
#
# batch 143, loss: 1.077491, accuracy: 63.3%
# Test Error:
# Accuracy: 61.7%, Avg loss: 1.140326
#
# batch 144, loss: 1.249170, accuracy: 58.6%
# Test Error:
# Accuracy: 61.6%, Avg loss: 1.142421
#
# batch 145, loss: 1.189889, accuracy: 56.2%
# Test Error:
# Accuracy: 61.6%, Avg loss: 1.145338
#
# batch 146, loss: 1.288303, accuracy: 56.6%
# Test Error:
# Accuracy: 61.6%, Avg loss: 1.144365
#
# batch 147, loss: 1.036508, accuracy: 66.8%
# Test Error:
# Accuracy: 61.8%, Avg loss: 1.141714
#
# batch 148, loss: 1.159874, accuracy: 62.5%
# Test Error:
# Accuracy: 61.9%, Avg loss: 1.139336
#
# batch 149, loss: 1.232599, accuracy: 60.2%
# Test Error:
# Accuracy: 62.0%, Avg loss: 1.135860
#
# batch 150, loss: 1.010654, accuracy: 65.6%
# Test Error:
# Accuracy: 62.3%, Avg loss: 1.133455
#
# batch 151, loss: 1.061908, accuracy: 62.9%
# Test Error:
# Accuracy: 62.3%, Avg loss: 1.131094
#
# batch 152, loss: 1.131319, accuracy: 60.2%
# Test Error:
# Accuracy: 62.3%, Avg loss: 1.128260
#
# batch 153, loss: 1.016605, accuracy: 66.0%
# Test Error:
# Accuracy: 62.3%, Avg loss: 1.126246
#
# batch 154, loss: 1.114321, accuracy: 62.9%
# Test Error:
# Accuracy: 62.3%, Avg loss: 1.122654
#
# batch 155, loss: 1.126661, accuracy: 57.4%
# Test Error:
# Accuracy: 62.3%, Avg loss: 1.118733
#
# batch 156, loss: 1.169161, accuracy: 58.2%
# Test Error:
# Accuracy: 62.4%, Avg loss: 1.115093
#
# batch 157, loss: 1.085719, accuracy: 60.9%
# Test Error:
# Accuracy: 62.5%, Avg loss: 1.112674
#
# batch 158, loss: 1.137487, accuracy: 60.5%
# Test Error:
# Accuracy: 63.0%, Avg loss: 1.108087
#
# batch 159, loss: 1.142679, accuracy: 62.5%
# Test Error:
# Accuracy: 63.0%, Avg loss: 1.104625
#
# batch 160, loss: 1.051201, accuracy: 62.1%
# Test Error:
# Accuracy: 62.9%, Avg loss: 1.101484
#
# batch 161, loss: 1.240915, accuracy: 59.8%
# Test Error:
# Accuracy: 63.1%, Avg loss: 1.098859
#
# batch 162, loss: 1.114759, accuracy: 64.1%
# Test Error:
# Accuracy: 63.2%, Avg loss: 1.094867
#
# batch 163, loss: 1.083475, accuracy: 60.5%
# Test Error:
# Accuracy: 63.2%, Avg loss: 1.090607
#
# batch 164, loss: 1.176768, accuracy: 62.1%
# Test Error:
# Accuracy: 63.3%, Avg loss: 1.086444
#
# batch 165, loss: 0.987763, accuracy: 62.9%
# Test Error:
# Accuracy: 63.4%, Avg loss: 1.082128
#
# batch 166, loss: 1.060071, accuracy: 65.2%
# Test Error:
# Accuracy: 63.4%, Avg loss: 1.078871
#
# batch 167, loss: 1.147137, accuracy: 62.5%
# Test Error:
# Accuracy: 63.4%, Avg loss: 1.078444
#
# batch 168, loss: 1.068555, accuracy: 62.5%
# Test Error:
# Accuracy: 63.3%, Avg loss: 1.077952
#
# batch 169, loss: 0.969360, accuracy: 67.6%
# Test Error:
# Accuracy: 63.3%, Avg loss: 1.076990
#
# batch 170, loss: 1.249705, accuracy: 60.2%
# Test Error:
# Accuracy: 63.2%, Avg loss: 1.076857
#
# batch 171, loss: 1.061949, accuracy: 63.3%
# Test Error:
# Accuracy: 63.2%, Avg loss: 1.075717
#
# batch 172, loss: 1.179620, accuracy: 59.8%
# Test Error:
# Accuracy: 63.1%, Avg loss: 1.074097
#
# batch 173, loss: 0.990802, accuracy: 64.5%
# Test Error:
# Accuracy: 63.2%, Avg loss: 1.073185
#
# batch 174, loss: 1.035042, accuracy: 61.7%
# Test Error:
# Accuracy: 63.3%, Avg loss: 1.070879
#
# batch 175, loss: 1.057009, accuracy: 63.7%
# Test Error:
# Accuracy: 63.4%, Avg loss: 1.067660
#
# batch 176, loss: 1.163253, accuracy: 55.5%
# Test Error:
# Accuracy: 63.4%, Avg loss: 1.063685
#
# batch 177, loss: 1.145611, accuracy: 62.1%
# Test Error:
# Accuracy: 63.6%, Avg loss: 1.059214
#
# batch 178, loss: 1.029748, accuracy: 64.5%
# Test Error:
# Accuracy: 63.6%, Avg loss: 1.054869
#
# batch 179, loss: 1.040050, accuracy: 61.7%
# Test Error:
# Accuracy: 64.0%, Avg loss: 1.049883
#
# batch 180, loss: 1.155020, accuracy: 61.7%
# Test Error:
# Accuracy: 64.2%, Avg loss: 1.044585
#
# batch 181, loss: 1.063484, accuracy: 60.5%
# Test Error:
# Accuracy: 64.4%, Avg loss: 1.038556
#
# batch 182, loss: 1.120919, accuracy: 60.5%
# Test Error:
# Accuracy: 64.6%, Avg loss: 1.034147
#
# batch 183, loss: 1.015750, accuracy: 64.8%
# Test Error:
# Accuracy: 64.9%, Avg loss: 1.031638
#
# batch 184, loss: 0.997659, accuracy: 66.4%
# Test Error:
# Accuracy: 65.0%, Avg loss: 1.029848
#
# batch 185, loss: 1.085102, accuracy: 62.5%
# Test Error:
# Accuracy: 65.0%, Avg loss: 1.029906
#
# batch 186, loss: 1.017079, accuracy: 67.6%
# Test Error:
# Accuracy: 65.3%, Avg loss: 1.030512
#
# batch 187, loss: 1.117728, accuracy: 61.3%
# Test Error:
# Accuracy: 65.2%, Avg loss: 1.030886
#
# batch 188, loss: 1.073042, accuracy: 65.2%
# Test Error:
# Accuracy: 65.4%, Avg loss: 1.028270
#
# batch 189, loss: 1.099439, accuracy: 62.5%
# Test Error:
# Accuracy: 65.3%, Avg loss: 1.025858
#
# batch 190, loss: 1.080727, accuracy: 62.9%
# Test Error:
# Accuracy: 65.5%, Avg loss: 1.023988
#
# batch 191, loss: 1.066498, accuracy: 61.7%
# Test Error:
# Accuracy: 65.7%, Avg loss: 1.022783
#
# batch 192, loss: 1.079978, accuracy: 63.7%
# Test Error:
# Accuracy: 65.8%, Avg loss: 1.022192
#
# batch 193, loss: 1.195514, accuracy: 57.8%
# Test Error:
# Accuracy: 65.7%, Avg loss: 1.023245
#
# batch 194, loss: 1.087391, accuracy: 64.5%
# Test Error:
# Accuracy: 65.6%, Avg loss: 1.024418
#
# batch 195, loss: 1.156043, accuracy: 66.0%
# Test Error:
# Accuracy: 65.6%, Avg loss: 1.024216
#
# batch 196, loss: 1.132010, accuracy: 61.3%
# Test Error:
# Accuracy: 65.5%, Avg loss: 1.024522
#
# batch 197, loss: 1.012178, accuracy: 66.8%
# Test Error:
# Accuracy: 65.5%, Avg loss: 1.025501
#
# batch 198, loss: 0.976641, accuracy: 64.1%
# Test Error:
# Accuracy: 65.5%, Avg loss: 1.024287
#
# batch 199, loss: 1.077298, accuracy: 61.7%
# Test Error:
# Accuracy: 65.5%, Avg loss: 1.022692
#
# batch 200, loss: 1.172248, accuracy: 59.0%
# Test Error:
# Accuracy: 65.7%, Avg loss: 1.023195
#
# batch 201, loss: 1.354059, accuracy: 57.0%
# Test Error:
# Accuracy: 65.7%, Avg loss: 1.022424
#
# batch 202, loss: 1.036550, accuracy: 62.5%
# Test Error:
# Accuracy: 65.7%, Avg loss: 1.020759
#
# batch 203, loss: 0.927267, accuracy: 70.3%
# Test Error:
# Accuracy: 65.8%, Avg loss: 1.019434
#
# batch 204, loss: 1.090978, accuracy: 66.8%
# Test Error:
# Accuracy: 65.6%, Avg loss: 1.017945
#
# batch 205, loss: 1.044204, accuracy: 66.0%
# Test Error:
# Accuracy: 65.6%, Avg loss: 1.016574
#
# batch 206, loss: 1.005201, accuracy: 64.1%
# Test Error:
# Accuracy: 65.8%, Avg loss: 1.015029
#
# batch 207, loss: 1.004770, accuracy: 67.6%
# Test Error:
# Accuracy: 65.8%, Avg loss: 1.013308
#
# batch 208, loss: 0.895352, accuracy: 71.1%
# Test Error:
# Accuracy: 66.0%, Avg loss: 1.010916
#
# batch 209, loss: 1.130272, accuracy: 62.1%
# Test Error:
# Accuracy: 66.0%, Avg loss: 1.008372
#
# batch 210, loss: 1.006739, accuracy: 67.2%
# Test Error:
# Accuracy: 66.2%, Avg loss: 1.005486
#
# batch 211, loss: 0.998841, accuracy: 69.5%
# Test Error:
# Accuracy: 66.2%, Avg loss: 1.002780
#
# batch 212, loss: 1.022575, accuracy: 62.5%
# Test Error:
# Accuracy: 66.3%, Avg loss: 0.999600
#
# batch 213, loss: 0.956372, accuracy: 66.8%
# Test Error:
# Accuracy: 66.3%, Avg loss: 0.997709
#
# batch 214, loss: 0.963384, accuracy: 68.0%
# Test Error:
# Accuracy: 66.3%, Avg loss: 0.996744
#
# batch 215, loss: 0.907189, accuracy: 70.3%
# Test Error:
# Accuracy: 66.5%, Avg loss: 0.994624
#
# batch 216, loss: 1.063478, accuracy: 68.8%
# Test Error:
# Accuracy: 66.4%, Avg loss: 0.993185
#
# batch 217, loss: 0.943729, accuracy: 68.4%
# Test Error:
# Accuracy: 66.4%, Avg loss: 0.993010
#
# batch 218, loss: 1.038826, accuracy: 68.8%
# Test Error:
# Accuracy: 66.4%, Avg loss: 0.992782
#
# batch 219, loss: 0.978451, accuracy: 70.3%
# Test Error:
# Accuracy: 66.3%, Avg loss: 0.993864
#
# batch 220, loss: 0.987223, accuracy: 66.4%
# Test Error:
# Accuracy: 66.2%, Avg loss: 0.995456
#
# batch 221, loss: 0.993468, accuracy: 65.6%
# Test Error:
# Accuracy: 66.2%, Avg loss: 0.998378
#
# batch 222, loss: 1.010656, accuracy: 69.1%
# Test Error:
# Accuracy: 66.3%, Avg loss: 0.999323
#
# batch 223, loss: 1.131175, accuracy: 60.2%
# Test Error:
# Accuracy: 66.3%, Avg loss: 1.000040
#
# batch 224, loss: 1.064664, accuracy: 61.3%
# Test Error:
# Accuracy: 66.1%, Avg loss: 1.001928
#
# batch 225, loss: 1.058256, accuracy: 66.0%
# Test Error:
# Accuracy: 66.1%, Avg loss: 1.002832
#
# batch 226, loss: 0.969186, accuracy: 67.2%
# Test Error:
# Accuracy: 66.1%, Avg loss: 1.002134
#
# batch 227, loss: 0.932786, accuracy: 66.8%
# Test Error:
# Accuracy: 66.1%, Avg loss: 0.998653
#
# batch 228, loss: 0.819084, accuracy: 71.1%
# Test Error:
# Accuracy: 66.1%, Avg loss: 0.995409
#
# batch 229, loss: 1.092045, accuracy: 62.1%
# Test Error:
# Accuracy: 66.2%, Avg loss: 0.988124
#
# batch 230, loss: 1.039489, accuracy: 63.7%
# Test Error:
# Accuracy: 66.4%, Avg loss: 0.982770
#
# batch 231, loss: 1.047424, accuracy: 64.1%
# Test Error:
# Accuracy: 66.6%, Avg loss: 0.977954
#
# batch 232, loss: 1.078934, accuracy: 62.9%
# Test Error:
# Accuracy: 66.6%, Avg loss: 0.973171
#
# batch 233, loss: 0.985292, accuracy: 65.2%
# Test Error:
# Accuracy: 66.7%, Avg loss: 0.967867
#
# batch 234, loss: 1.118952, accuracy: 57.3%
# Test Error:
# Accuracy: 66.9%, Avg loss: 0.961723
#
# Epoch 2
# -------------------------------
# batch 0, loss: 1.071497, accuracy: 64.8%
# Test Error:
# Accuracy: 67.3%, Avg loss: 0.955369
#
# batch 1, loss: 0.964014, accuracy: 65.2%
# Test Error:
# Accuracy: 67.5%, Avg loss: 0.948756
#
# batch 2, loss: 0.973932, accuracy: 66.4%
# Test Error:
# Accuracy: 67.7%, Avg loss: 0.943760
#
# batch 3, loss: 0.929158, accuracy: 67.6%
# Test Error:
# Accuracy: 68.0%, Avg loss: 0.940949
#
# batch 4, loss: 1.051688, accuracy: 65.2%
# Test Error:
# Accuracy: 68.2%, Avg loss: 0.937998
#
# batch 5, loss: 0.914531, accuracy: 69.5%
# Test Error:
# Accuracy: 68.2%, Avg loss: 0.935454
#
# batch 6, loss: 1.011126, accuracy: 68.8%
# Test Error:
# Accuracy: 68.4%, Avg loss: 0.932711
#
# batch 7, loss: 0.934042, accuracy: 64.8%
# Test Error:
# Accuracy: 68.4%, Avg loss: 0.931622
#
# batch 8, loss: 1.154038, accuracy: 60.2%
# Test Error:
# Accuracy: 68.5%, Avg loss: 0.932035
#
# batch 9, loss: 0.944763, accuracy: 67.6%
# Test Error:
# Accuracy: 68.5%, Avg loss: 0.931126
#
# batch 10, loss: 0.993056, accuracy: 64.8%
# Test Error:
# Accuracy: 68.5%, Avg loss: 0.929755
#
# batch 11, loss: 0.941033, accuracy: 68.8%
# Test Error:
# Accuracy: 68.7%, Avg loss: 0.927390
#
# batch 12, loss: 0.948780, accuracy: 70.3%
# Test Error:
# Accuracy: 68.7%, Avg loss: 0.925519
#
# batch 13, loss: 1.031550, accuracy: 62.9%
# Test Error:
# Accuracy: 68.9%, Avg loss: 0.922054
#
# batch 14, loss: 0.945718, accuracy: 65.6%
# Test Error:
# Accuracy: 69.0%, Avg loss: 0.917393
#
# batch 15, loss: 0.967832, accuracy: 67.2%
# Test Error:
# Accuracy: 69.3%, Avg loss: 0.910561
#
# batch 16, loss: 0.818994, accuracy: 72.7%
# Test Error:
# Accuracy: 69.6%, Avg loss: 0.903975
#
# batch 17, loss: 0.962841, accuracy: 64.8%
# Test Error:
# Accuracy: 69.6%, Avg loss: 0.897823
#
# batch 18, loss: 0.795321, accuracy: 71.9%
# Test Error:
# Accuracy: 69.8%, Avg loss: 0.892575
#
# batch 19, loss: 0.971533, accuracy: 65.2%
# Test Error:
# Accuracy: 70.0%, Avg loss: 0.889327
#
# batch 20, loss: 0.948575, accuracy: 65.2%
# Test Error:
# Accuracy: 70.0%, Avg loss: 0.886541
#
# batch 21, loss: 0.757086, accuracy: 71.9%
# Test Error:
# Accuracy: 70.0%, Avg loss: 0.883767
#
# batch 22, loss: 1.043030, accuracy: 63.7%
# Test Error:
# Accuracy: 70.2%, Avg loss: 0.881581
#
# batch 23, loss: 0.743527, accuracy: 76.2%
# Test Error:
# Accuracy: 70.1%, Avg loss: 0.879739
#
# batch 24, loss: 0.916873, accuracy: 69.1%
# Test Error:
# Accuracy: 70.2%, Avg loss: 0.878213
#
# batch 25, loss: 0.942023, accuracy: 66.0%
# Test Error:
# Accuracy: 70.2%, Avg loss: 0.876634
#
# batch 26, loss: 0.897330, accuracy: 68.4%
# Test Error:
# Accuracy: 70.2%, Avg loss: 0.874647
#
# batch 27, loss: 0.815785, accuracy: 74.2%
# Test Error:
# Accuracy: 70.3%, Avg loss: 0.872954
#
# batch 28, loss: 0.952421, accuracy: 70.7%
# Test Error:
# Accuracy: 70.4%, Avg loss: 0.872382
#
# batch 29, loss: 0.944857, accuracy: 71.1%
# Test Error:
# Accuracy: 70.6%, Avg loss: 0.872187
#
# batch 30, loss: 0.808800, accuracy: 71.5%
# Test Error:
# Accuracy: 70.5%, Avg loss: 0.871077
#
# batch 31, loss: 0.908260, accuracy: 68.8%
# Test Error:
# Accuracy: 70.5%, Avg loss: 0.869047
#
# batch 32, loss: 0.791791, accuracy: 73.4%
# Test Error:
# ...
# Test Error:
# Accuracy: 89.3%, Avg loss: 0.405635
#
# batch 51, loss: 0.501826, accuracy: 88.3%
# Test Error:
# Accuracy: 89.3%, Avg loss: 0.408410
#
# batch 52, loss: 0.384864, accuracy: 88.7%
# Test Error:
# Accuracy: 89.2%, Avg loss: 0.410834
#
# batch 53, loss: 0.483060, accuracy: 87.1%
# Test Error:
# Accuracy: 89.2%, Avg loss: 0.413026
#
# batch 54, loss: 0.334797, accuracy: 91.4%
# Test Error:
# Accuracy: 89.0%, Avg loss: 0.415405
#
# batch 55, loss: 0.312301, accuracy: 92.6%
# Test Error:
# Accuracy: 88.9%, Avg loss: 0.417262
#
# batch 56, loss: 0.363767, accuracy: 90.2%
# Test Error:
# Accuracy: 89.0%, Avg loss: 0.419096
#
# batch 57, loss: 0.399796, accuracy: 88.7%
# Test Error:
# Accuracy: 89.0%, Avg loss: 0.420691
#
# batch 58, loss: 0.353950, accuracy: 91.8%
# Test Error:
# Accuracy: 89.1%, Avg loss: 0.421753
#
# batch 59, loss: 0.457300, accuracy: 87.5%
# Test Error:
# Accuracy: 89.2%, Avg loss: 0.421937
#
# batch 60, loss: 0.535681, accuracy: 84.4%
# Test Error:
# Accuracy: 89.1%, Avg loss: 0.422853
#
# batch 61, loss: 0.483841, accuracy: 88.7%
# Test Error:
# Accuracy: 89.2%, Avg loss: 0.422139
#
# batch 62, loss: 0.348839, accuracy: 90.2%
# Test Error:
# Accuracy: 89.3%, Avg loss: 0.422229
#
# batch 63, loss: 0.496629, accuracy: 88.7%
# Test Error:
# Accuracy: 89.2%, Avg loss: 0.422843
#
# batch 64, loss: 0.466289, accuracy: 88.3%
# Test Error:
# Accuracy: 89.2%, Avg loss: 0.422717
#
# batch 65, loss: 0.398302, accuracy: 88.3%
# Test Error:
# Accuracy: 89.3%, Avg loss: 0.422685
#
# batch 66, loss: 0.344218, accuracy: 89.5%
# Test Error:
# Accuracy: 89.3%, Avg loss: 0.421812
#
# batch 67, loss: 0.536638, accuracy: 87.1%
# Test Error:
# Accuracy: 89.3%, Avg loss: 0.420897
#
# batch 68, loss: 0.490675, accuracy: 85.5%
# Test Error:
# Accuracy: 89.4%, Avg loss: 0.419832
#
# batch 69, loss: 0.339907, accuracy: 89.8%
# Test Error:
# Accuracy: 89.6%, Avg loss: 0.419177
#
# batch 70, loss: 0.434891, accuracy: 87.9%
# Test Error:
# Accuracy: 89.7%, Avg loss: 0.418239
#
# batch 71, loss: 0.464185, accuracy: 88.7%
# Test Error:
# Accuracy: 89.8%, Avg loss: 0.417038
#
# batch 72, loss: 0.373372, accuracy: 91.4%
# Test Error:
# Accuracy: 89.8%, Avg loss: 0.416265
#
# batch 73, loss: 0.441230, accuracy: 87.1%
# Test Error:
# Accuracy: 89.8%, Avg loss: 0.415686
#
# batch 74, loss: 0.362900, accuracy: 89.1%
# Test Error:
# Accuracy: 89.7%, Avg loss: 0.415493
#
# batch 75, loss: 0.302410, accuracy: 92.6%
# Test Error:
# Accuracy: 89.7%, Avg loss: 0.415133
#
# batch 76, loss: 0.492285, accuracy: 89.5%
# Test Error:
# Accuracy: 89.7%, Avg loss: 0.414136
#
# batch 77, loss: 0.395897, accuracy: 90.6%
# Test Error:
# Accuracy: 89.8%, Avg loss: 0.413370
#
# batch 78, loss: 0.650938, accuracy: 85.5%
# Test Error:
# Accuracy: 89.8%, Avg loss: 0.412782
#
# batch 79, loss: 0.329772, accuracy: 91.4%
# Test Error:
# Accuracy: 89.7%, Avg loss: 0.412452
#
# batch 80, loss: 0.420110, accuracy: 90.2%
# Test Error:
# Accuracy: 89.7%, Avg loss: 0.411508
#
# batch 81, loss: 0.424161, accuracy: 88.3%
# Test Error:
# Accuracy: 89.6%, Avg loss: 0.410693
#
# batch 82, loss: 0.389675, accuracy: 89.1%
# Test Error:
# Accuracy: 89.5%, Avg loss: 0.410023
#
# batch 83, loss: 0.403235, accuracy: 87.5%
# Test Error:
# Accuracy: 89.6%, Avg loss: 0.408406
#
# batch 84, loss: 0.355010, accuracy: 88.3%
# Test Error:
# Accuracy: 89.6%, Avg loss: 0.407164
#
# batch 85, loss: 0.357847, accuracy: 91.8%
# Test Error:
# Accuracy: 89.4%, Avg loss: 0.405660
#
# batch 86, loss: 0.290190, accuracy: 93.0%
# Test Error:
# Accuracy: 89.5%, Avg loss: 0.404403
#
# batch 87, loss: 0.514727, accuracy: 88.3%
# Test Error:
# Accuracy: 89.5%, Avg loss: 0.402298
#
# batch 88, loss: 0.525018, accuracy: 87.5%
# Test Error:
# Accuracy: 89.7%, Avg loss: 0.399876
#
# batch 89, loss: 0.309313, accuracy: 90.6%
# Test Error:
# Accuracy: 89.6%, Avg loss: 0.397905
#
# batch 90, loss: 0.368101, accuracy: 89.1%
# Test Error:
# Accuracy: 89.6%, Avg loss: 0.395569
#
# batch 91, loss: 0.547372, accuracy: 85.5%
# Test Error:
# Accuracy: 89.5%, Avg loss: 0.394650
# Traceback (most recent call last):
#   File "/tmp/ipykernel_10694/1872670006.py", line 27, in train_snn
#     train_loop_snn(es_model,train_dataloader, val_dataloader, cross_entropy, run.config.nb_model_samples, run)
#   File "/tmp/ipykernel_10694/3273294460.py", line 45, in train_loop_snn
#     for model in es_model.samples(nb_model_samples):
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wyx/darwin_neuron/EvolutionStrategy.py", line 112, in samples
#     yield(self._params_to_model(param_list))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wyx/darwin_neuron/EvolutionStrategy.py", line 100, in _params_to_model
#     model = self.Model(*self.model_args).to(device)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/wyx/miniconda3/envs/snn/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1340, in to
#     return self._apply(convert)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/wyx/miniconda3/envs/snn/lib/python3.12/site-packages/torch/nn/modules/module.py", line 900, in _apply
#     module._apply(fn)
#   File "/home/wyx/miniconda3/envs/snn/lib/python3.12/site-packages/torch/nn/modules/module.py", line 927, in _apply
#     param_applied = fn(param)
#                     ^^^^^^^^^
#   File "/home/wyx/miniconda3/envs/snn/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1326, in convert
#     return t.to(
#            ^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[6], line 27, in train_snn()
#
#      26 # train the model
#
# ---> 27 train_loop_snn(es_model,train_dataloader, val_dataloader, cross_entropy, run.config.nb_model_samples, run)
#
#
#
# Cell In[5], line 45, in train_loop_snn(es_model, train_dataloader, val_dataloader, loss_fn, nb_model_samples, run)
#
#      44 samples_loss = []
#
# ---> 45 for model in es_model.samples(nb_model_samples):
#
#      46     loss, _ = _run_snn_on_batch(model, x, y, loss_fn)
#
#
#
# File ~/darwin_neuron/EvolutionStrategy.py:112, in ESModel.samples(self, sample_size)
#
#     111 param_list = [es_param.samples[i] for es_param in self.param_dict.values()]
#
# --> 112 yield(self._params_to_model(param_list))
#
#
#
# File ~/darwin_neuron/EvolutionStrategy.py:100, in ESModel._params_to_model(self, param_list)
#
#      99 def _params_to_model(self, param_list):
#
# --> 100     model = self.Model(*self.model_args).to(device)
#
#     101     for i, param in enumerate(model.parameters()):
#
#
#
# File ~/miniconda3/envs/snn/lib/python3.12/site-packages/torch/nn/modules/module.py:1340, in Module.to(self, *args, **kwargs)
#
#    1338             raise
#
# -> 1340 return self._apply(convert)
#
#
#
# File ~/miniconda3/envs/snn/lib/python3.12/site-packages/torch/nn/modules/module.py:900, in Module._apply(self, fn, recurse)
#
#     899     for module in self.children():
#
# --> 900         module._apply(fn)
#
#     902 def compute_should_use_set_data(tensor, tensor_applied):
#
#
#
# File ~/miniconda3/envs/snn/lib/python3.12/site-packages/torch/nn/modules/module.py:927, in Module._apply(self, fn, recurse)
#
#     926 with torch.no_grad():
#
# --> 927     param_applied = fn(param)
#
#     928 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#
#
#
# File ~/miniconda3/envs/snn/lib/python3.12/site-packages/torch/nn/modules/module.py:1326, in Module.to.<locals>.convert(t)
#
#    1320         return t.to(
#
#    1321             device,
#
#    1322             dtype if t.is_floating_point() or t.is_complex() else None,
#
#    1323             non_blocking,
#
#    1324             memory_format=convert_to_format,
#
#    1325         )
#
# -> 1326     return t.to(
#
#    1327         device,
#
#    1328         dtype if t.is_floating_point() or t.is_complex() else None,
#
#    1329         non_blocking,
#
#    1330     )
#
#    1331 except NotImplementedError as e:
#
#
#
# KeyboardInterrupt:
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# BrokenPipeError                           Traceback (most recent call last)
#
# Cell In[6], line 29
#
#      26             # train the model
#
#      27             train_loop_snn(es_model,train_dataloader, val_dataloader, cross_entropy, run.config.nb_model_samples, run)
#
# ---> 29 train_snn()
#
#
#
# Cell In[6], line 7, in train_snn()
#
#       2 run_name = 'first-attempt'
#
#       3 config = {'nb_model_samples': 1000,
#
#       4           'std': 0.05,
#
#       5           'lr': 0.01,
#
#       6           'epochs': 25}
#
# ----> 7 with torch.no_grad(), wandb.init(entity = 'DarwinNeuron', project = 'ES-CNN-MNIST', name=run_name, config=config) as run:
#
#       8     train_dataloader = torch.utils.data.DataLoader(
#
#       9         datasets.MNIST('data', train=True, download=True,
#
#      10                             transform=Compose([
#
#    (...)
#
#      13                             ])),
#
#      14         batch_size=256, shuffle=True)
#
#      16     val_dataloader = torch.utils.data.DataLoader(
#
#      17         datasets.MNIST('data', train=False, download=True,
#
#      18                                     transform=Compose([
#
#    (...)
#
#      21                                     ])),
#
#      22         batch_size=1000, shuffle=True)
#
#
#
# File ~/miniconda3/envs/snn/lib/python3.12/site-packages/wandb/sdk/wandb_run.py:3719, in Run.__exit__(self, exc_type, exc_val, exc_tb)
#
#    3717     traceback.print_exception(exc_type, exc_val, exc_tb)
#
#    3718 exit_code = 1 if exception_raised else 0
#
# -> 3719 self._finish(exit_code=exit_code)
#
#    3720 return not exception_raised
#
#
#
# File ~/miniconda3/envs/snn/lib/python3.12/site-packages/wandb/sdk/wandb_run.py:387, in _log_to_run.<locals>.wrapper(self, *args, **kwargs)
#
#     384     run_id = self._attach_id
#
#     386 with wb_logging.log_to_run(run_id):
#
# --> 387     return func(self, *args, **kwargs)
#
#
#
# File ~/miniconda3/envs/snn/lib/python3.12/site-packages/wandb/sdk/wandb_run.py:2190, in Run._finish(self, exit_code)
#
#    2184 @_log_to_run
#
#    2185 def _finish(
#
#    2186     self,
#
#    2187     exit_code: int | None = None,
#
#    2188 ) -> None:
#
#    2189     logger.info(f"finishing run {self._get_path()}")
#
# -> 2190     with telemetry.context(run=self) as tel:
#
#    2191         tel.feature.finish = True
#
#    2193     # Run hooks that need to happen before the last messages to the
#
#    2194     # internal service, like Jupyter hooks.
#
#
#
# File ~/miniconda3/envs/snn/lib/python3.12/site-packages/wandb/sdk/lib/telemetry.py:42, in _TelemetryObject.__exit__(self, exctype, excinst, exctb)
#
#      40 if not self._run:
#
#      41     return
#
# ---> 42 self._run._telemetry_callback(self._obj)
#
#
#
# File ~/miniconda3/envs/snn/lib/python3.12/site-packages/wandb/sdk/wandb_run.py:783, in Run._telemetry_callback(self, telem_obj)
#
#     781 self._telemetry_obj.MergeFrom(telem_obj)
#
#     782 self._telemetry_obj_dirty = True
#
# --> 783 self._telemetry_flush()
#
#
#
# File ~/miniconda3/envs/snn/lib/python3.12/site-packages/wandb/sdk/wandb_run.py:796, in Run._telemetry_flush(self)
#
#     794 if serialized == self._telemetry_obj_flushed:
#
#     795     return
#
# --> 796 self._backend.interface._publish_telemetry(self._telemetry_obj)
#
#     797 self._telemetry_obj_flushed = serialized
#
#     798 self._telemetry_obj_dirty = False
#
#
#
# File ~/miniconda3/envs/snn/lib/python3.12/site-packages/wandb/sdk/interface/interface_shared.py:60, in InterfaceShared._publish_telemetry(self, telem)
#
#      58 def _publish_telemetry(self, telem: tpb.TelemetryRecord) -> None:
#
#      59     rec = self._make_record(telemetry=telem)
#
# ---> 60     self._publish(rec)
#
#
#
# File ~/miniconda3/envs/snn/lib/python3.12/site-packages/wandb/sdk/interface/interface_sock.py:39, in InterfaceSock._publish(self, record, local)
#
#      37 def _publish(self, record: "pb.Record", local: Optional[bool] = None) -> None:
#
#      38     self._assign(record)
#
# ---> 39     self._sock_client.send_record_publish(record)
#
#
#
# File ~/miniconda3/envs/snn/lib/python3.12/site-packages/wandb/sdk/lib/sock_client.py:174, in SockClient.send_record_publish(self, record)
#
#     172 server_req.request_id = record.control.mailbox_slot
#
#     173 server_req.record_publish.CopyFrom(record)
#
# --> 174 self.send_server_request(server_req)
#
#
#
# File ~/miniconda3/envs/snn/lib/python3.12/site-packages/wandb/sdk/lib/sock_client.py:154, in SockClient.send_server_request(self, msg)
#
#     153 def send_server_request(self, msg: spb.ServerRequest) -> None:
#
# --> 154     self._send_message(msg)
#
#
#
# File ~/miniconda3/envs/snn/lib/python3.12/site-packages/wandb/sdk/lib/sock_client.py:151, in SockClient._send_message(self, msg)
#
#     149 header = struct.pack("<BI", ord("W"), raw_size)
#
#     150 with self._lock:
#
# --> 151     self._sendall_with_error_handle(header + data)
#
#
#
# File ~/miniconda3/envs/snn/lib/python3.12/site-packages/wandb/sdk/lib/sock_client.py:130, in SockClient._sendall_with_error_handle(self, data)
#
#     128 start_time = time.monotonic()
#
#     129 try:
#
# --> 130     sent = self._sock.send(data)
#
#     131     # sent equal to 0 indicates a closed socket
#
#     132     if sent == 0:
#
#
#
# BrokenPipeError: [Errno 32] Broken pipe
# Error in callback <bound method _WandbInit._pause_backend of <wandb.sdk.wandb_init._WandbInit object at 0x7f74e2af9880>> (for post_run_cell), with arguments args (<ExecutionResult object at 7f74cb57f4a0, execution_count=6 error_before_exec=None error_in_exec=[Errno 32] Broken pipe info=<ExecutionInfo object at 7f74cb49ede0, raw_cell="def train_snn():
#     run_name = 'first-attempt'.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell://wsl%2Bubuntu-22.04/home/wyx/darwin_neuron/ES-CNN-MNIST.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
#
# BrokenPipeError                           Traceback (most recent call last)
#
# File ~/miniconda3/envs/snn/lib/python3.12/site-packages/wandb/sdk/wandb_init.py:547, in _WandbInit._pause_backend(self, *args, **kwargs)
#
#     545 if self.backend.interface is not None:
#
#     546     self._logger.info("pausing backend")  # type: ignore
#
# --> 547     self.backend.interface.publish_pause()
#
#
#
# File ~/miniconda3/envs/snn/lib/python3.12/site-packages/wandb/sdk/interface/interface.py:769, in InterfaceBase.publish_pause(self)
#
#     767 def publish_pause(self) -> None:
#
#     768     pause = pb.PauseRequest()
#
# --> 769     self._publish_pause(pause)
#
#
#
# File ~/miniconda3/envs/snn/lib/python3.12/site-packages/wandb/sdk/interface/interface_shared.py:289, in InterfaceShared._publish_pause(self, pause)
#
#     287 def _publish_pause(self, pause: pb.PauseRequest) -> None:
#
#     288     rec = self._make_request(pause=pause)
#
# --> 289     self._publish(rec)
#
#
#
# File ~/miniconda3/envs/snn/lib/python3.12/site-packages/wandb/sdk/interface/interface_sock.py:39, in InterfaceSock._publish(self, record, local)
#
#      37 def _publish(self, record: "pb.Record", local: Optional[bool] = None) -> None:
#
#      38     self._assign(record)
#
# ---> 39     self._sock_client.send_record_publish(record)
#
#
#
# File ~/miniconda3/envs/snn/lib/python3.12/site-packages/wandb/sdk/lib/sock_client.py:174, in SockClient.send_record_publish(self, record)
#
#     172 server_req.request_id = record.control.mailbox_slot
#
#     173 server_req.record_publish.CopyFrom(record)
#
# --> 174 self.send_server_request(server_req)
#
#
#
# File ~/miniconda3/envs/snn/lib/python3.12/site-packages/wandb/sdk/lib/sock_client.py:154, in SockClient.send_server_request(self, msg)
#
#     153 def send_server_request(self, msg: spb.ServerRequest) -> None:
#
# --> 154     self._send_message(msg)
#
#
#
# File ~/miniconda3/envs/snn/lib/python3.12/site-packages/wandb/sdk/lib/sock_client.py:151, in SockClient._send_message(self, msg)
#
#     149 header = struct.pack("<BI", ord("W"), raw_size)
#
#     150 with self._lock:
#
# --> 151     self._sendall_with_error_handle(header + data)
#
#
#
# File ~/miniconda3/envs/snn/lib/python3.12/site-packages/wandb/sdk/lib/sock_client.py:130, in SockClient._sendall_with_error_handle(self, data)
#
#     128 start_time = time.monotonic()
#
#     129 try:
#
# --> 130     sent = self._sock.send(data)
#
#     131     # sent equal to 0 indicates a closed socket
#
#     132     if sent == 0:
#
#
#
# BrokenPipeError: [Errno 32] Broken pipe

# %% [markdown]
# Observation:
# - As I increase the std of parameters, the loss start to increase as well. When std = 1, the loss blows up.
#     - can i normalize layer to solve this problem? the output of each layer shouldn't be affected so much by the initialization of weights? Also, what makes this blow up (how does the weights work here)?
# - Adaptive STD ??!!! from large to small

# %% [markdown]
# ## 3. Single Neuron Optimization Task

# %% [markdown]
# ES with SNN was a failure so we will try a simpler one parameter model mentioned in the ES paper. The task is to minimize number of spikes

# %%
from EvolutionStrategy import ESModel
from Utilities import spike_count

from torch import optim
import wandb

class SingleNeuron(nn.Module):
    def __init__(self):
        super().__init__()
        self.neuron = snn.Leaky(beta=0.85, learn_beta=False, threshold=0.5)
        self.i_app = torch.nn.parameter.Parameter(torch.tensor([2.,]),requires_grad=False)
    def forward(self):
        mem = self.neuron.init_leaky()
        spk_rec = []
        for _ in range(100):
            spk, mem = self.neuron(self.i_app, mem)    
            spk_rec.append(spk)
        return torch.stack(spk_rec, dim=0)        

def train_single_neuron():
    config = {
        'std': 1,
        'lr': 0.01,
        'nb_sample': 100,
        'epochs': 1000
    }
    
    with torch.no_grad(), wandb.init(entity = 'DarwinNeuron', project = 'SingleNeuron', name = 'name?', config = config) as run:
        es_model = ESModel(Model=SingleNeuron, param_std = run.config.std, Optimizer=optim.Adam, lr = run.config.lr)
        run.log({'I_app': es_model.get_best_model().i_app.item()})
        for epoch in range(1, run.config.epochs + 1):            
            losses = []
            for model in es_model.samples(run.config.nb_sample):
                spike_train = model()
                model_loss = spike_count(spike_train).float()
                losses.append(model_loss)
                
            losses = torch.stack(losses)
            es_model.gradient_descent(losses)
            run.log({'I_app': es_model.get_best_model().i_app.item(), 
                     'estimated_loss': ESModel.estimated_loss(losses),
                     'val_loss': spike_count(es_model.get_best_model().forward())})
            print(f"loss: {losses.mean():>7f}")
            
        return es_model.get_best_model()

# best_neuron = train_single_neuron()
